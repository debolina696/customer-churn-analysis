# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/churn_clean_readable.csv")
df.head()
# Out:
#    ï»¿CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0              1   22  Female      25               14              4
# 1              2   41  Female      28               28              7
# 2              3   47    Male      27               10              2
# 3              4   35    Male       9               12              5
# 4              5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# ...

# %%
sns.countplot(x="Churn", data=df)
plt.title("Churn Distribution")
plt.show()

# %%
sns.countplot(x="Gender", hue="Churn", data=df)
plt.title("Churn by Gender")
plt.show()

sns.histplot(df["Age"], bins=20, hue=df["Churn"], multiple="stack")
plt.title("Age Distribution by Churn")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 plt.title("Churn by Gender")
#       3 plt.show()
# ----> 5 sns.histplot(df["Age"], bins=20, hue=df["Churn"], multiple="stack")
#       6 plt.title("Age Distribution by Churn")
#       7 plt.show()
#
# File /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages/seaborn/distributions.py:1379, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1358 def histplot(
#    1359     data=None, *,
#    1360     # Vector variables
#    (...)   1376     **kwargs,
#    1377 ):
# -> 1379     p = _DistributionPlotter(
#    1380         data=data,
# ...

# %%
sns.histplot(data=df, x="Age", bins=20, hue="Churn", multiple="stack")
plt.title("Age Distribution by Churn")
plt.show()

# %%
plt.figure(figsize=(10,6))
numeric_df = df.select_dtypes(include=['int64','float64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
sns.countplot(x="Subscription Type", hue="Churn", data=df)
plt.title("Churn by Subscription Type")
plt.show()

# %%
sns.countplot(x="Contract Length", hue="Churn", data=df)
plt.title("Churn by Contract Length")
plt.show()

# %%
sns.countplot(x="Subscription Type", hue="Churn", data=df)
plt.title("Churn by Subscription Type")
plt.show()

# %%
sns.boxplot(x="Churn", y="Support Calls", data=df)
plt.title("Support Calls vs Churn")
plt.show()

# %%
sns.boxplot(x="Churn", y="Payment Delay", data=df)
plt.title("Payment Delay vs Churn")
plt.show()
